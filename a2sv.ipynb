# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\Yibabe\Desktop\webscraping-1\scraped_data\A2SV Community Education - 2024 - Div 3 - Group 2 - progress sheet - Info Sheet.csv')

# %%
df
# Out:
#                                   l    Phone Number     Telegram Username  \
# 0              Biruk Chali Tessema    +251940675703             @brukcity
# 1             Abiy Shiferaw Chernet   +251973918873              @ABKodes
# 2           Dagim Gizachew Astatkie   +251906290648              @aion_ue
# 3         Mikiyas Alemayehu Mekonen   +251932380940      @mikiyalemyehu12
# 4                 Newal Yimam Birru   +251919977271             @newaleti
# 5     Estifanos Solomon Gebremedhin  +254 113584511             @estif_34
# 6             Yosef Solomon Teferra   +251944029792              @JosiSol
# 7         Meron Gebresilassie Bahru   +251984153951           @althea1214
# 8            Betelhem belete bekele   +251947742149              @revee21
# 9                         Yeabtsega   +251924384865             @Yeabsega
# 10           Eyosias Mulugeta Solko   +251900069944           @Iyosinator
# 11                Liben Adugna Wako   +251906169046              @liben12
# ...

# %%
# Filter rows where 'Institution' is 'Addis Ababa University'
filtered_df = df[df['Institution'] == 'Addis Ababa University']

# Print the filtered rows

# %%
filtered_df
# Out:
#                                   l   Phone Number Telegram Username  \
# 6             Yosef Solomon Teferra  +251944029792          @JosiSol
# 13             Henok Kinde Demelash              /        @Henhenrry
# 14                  Ermiyas Tesfaye  +251900648503          @black6t
# 20                  Tewobsta Seyoum  +251955363368        @esnt12_21
# 24  Ashenafi Bizuwork Gebreyohannes  +251961036231  @Winner_Manygold
# 26         BEGIZEW ZERIHUN AZIMERAW  +251960627431      @kuluamekeru
# 27           Samrawit Kahsay Tesfay  +251930603080       @Fumble_wit
# 28          Jibril Mustefa Mahammod  +251944189283       @FindMe1001
# 31             Biruk Demissie Lemma  +251906817873            @BDLB9
# 34          Ruth Gashahun Gebreyes   +251943921283            @INTL0
# 35           Mikiyas Fasil Demessie  +251903202155          @miky_21
# 38            HILLARY MENGESHA MAMO  +251904122980         @Fumblary
# 39             Kirubel Girma Adugna  +251967105556   @dancin_shadows
# ...

# %%
# Reset the index of the filtered DataFrame
filtered_df = filtered_df.reset_index(drop=True)

# Add a new column for sequential order starting from 1
filtered_df['Order'] = filtered_df.index + 1

# %%
filtered_df
# Out:
#                                   l   Phone Number Telegram Username  \
# 0             Yosef Solomon Teferra  +251944029792          @JosiSol
# 1              Henok Kinde Demelash              /        @Henhenrry
# 2                   Ermiyas Tesfaye  +251900648503          @black6t
# 3                   Tewobsta Seyoum  +251955363368        @esnt12_21
# 4   Ashenafi Bizuwork Gebreyohannes  +251961036231  @Winner_Manygold
# 5          BEGIZEW ZERIHUN AZIMERAW  +251960627431      @kuluamekeru
# 6            Samrawit Kahsay Tesfay  +251930603080       @Fumble_wit
# 7           Jibril Mustefa Mahammod  +251944189283       @FindMe1001
# 8              Biruk Demissie Lemma  +251906817873            @BDLB9
# 9           Ruth Gashahun Gebreyes   +251943921283            @INTL0
# 10           Mikiyas Fasil Demessie  +251903202155          @miky_21
# 11            HILLARY MENGESHA MAMO  +251904122980         @Fumblary
# 12             Kirubel Girma Adugna  +251967105556   @dancin_shadows
# ...

# %%
# Print the filtered DataFrame with sequential order
print(filtered_df[['Order', 'Name', 'Email', 'Institution']])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Print the filtered DataFrame with sequential order
# ----> 2 print(filtered_df[['Order', 'Name', 'Email', 'Institution']])
#
# File c:\Users\Yibabe\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4096, in DataFrame.__getitem__(self, key)
#    4094     if is_iterator(key):
#    4095         key = list(key)
# -> 4096     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4098 # take() does not accept boolean indexers
#    4099 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\Yibabe\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:6199, in Index._get_indexer_strict(self, key, axis_name)
#    6196 else:
#    6197     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...
